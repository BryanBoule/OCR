# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.data as data
import skimage.segmentation as seg
import skimage.filters as filters
import skimage.draw as draw
import skimage.color as color

from skimage import io

import os

# %%
path_to_image = './data/input/constat_1.jpg'

img_to_segment = io.imread(path_to_image)
io.imshow(img_to_segment)

# %%
def image_show(image, nrows=1, ncols=1, cmap='gray'):
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14, 14))
    ax.imshow(image, cmap='gray')
    ax.axis('off')
    return fig, ax

# %%
text = data.page()
image_show(text)
# Out:
# (<Figure size 1008x1008 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25e68116828>)

# %%
fig, ax = plt.subplots(1, 1)
ax.hist(text.ravel(), bins=32, range=[0, 256])
ax.set_xlim(0, 256);

# %%
img_to_segment.shape
# Out:
# (1050, 800, 3)

# %%
img_to_segment[:,:,1].shape
# Out:
# (1050, 800)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15,15))


# R
ax1.hist(img_to_segment[:,:,0].ravel(), bins=32, range=[0, 256])
ax1.set_xlim(0, 256);

# G
ax2.hist(img_to_segment[:,:,1].ravel(), bins=32, range=[0, 256])
ax2.set_xlim(0, 256);

# B
ax3.hist(img_to_segment[:,:,2].ravel(), bins=32, range=[0, 256])
ax3.set_xlim(0, 256);

# %%
img_to_segment_gray = color.rgb2gray(img_to_segment) 
image_show(img_to_segment_gray)
# Out:
# (<Figure size 1008x1008 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25e6a0ae748>)

# %%
def rectangle_points(resolution, coin_bas_gauche,long , larg):
    """
    Generate points which define a rectangle on an image.
    """   
    perim = 2*(long+larg)
    step = int(perim / resolution)
    
    cote_1 = 
    points_long = np.linspace(0, long, step)
    points_larg = np.linspace(0, larg, step)
    
    c = center[1] + radius*np.cos(radians)#polar co-ordinates
    r = center[0] + radius*np.sin(radians)
    
    return np.array([c, r]).T

# Exclude last point because a closed path should not have duplicate points
points = circle_points(200, [270, 230], 100)[:-1]

# %%
len(points)
# Out:
# 199

# %%
fig, ax = image_show(img_to_segment_gray)
ax.plot(points[:, 0], points[:, 1], '--r', lw=3)

# %%
# !pip install parsr-client
# Out:
# ...
#   Could not find a version that satisfies the requirement parsr-client (from versions: )
# No matching distribution found for parsr-client

# %%
# !pip install ParsrClient
# Out:
# ...
#   Could not find a version that satisfies the requirement ParsrClient (from versions: )
# No matching distribution found for ParsrClient
